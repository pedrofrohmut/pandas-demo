# %%
import pandas as pd
import numpy as np

# %%
# Set DataFrame and DataFrameSchema
df = pd.read_csv(
    "data/survey_results_public.csv", 
    index_col = "Respondent",
    na_values = ["NA", "Missing"]
)
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col = "Column")
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)

# %%
# DataFrame Head (default = 5). Sorted by Column name ascending
df.head().reindex(sorted(df.columns), axis = 1)
# Out:
#              Age Age1stCode BetterLife  \
# Respondent
# 1           14.0         10        Yes
# 2           19.0         17        Yes
# 3           28.0         22        Yes
# 4           22.0         16        Yes
# 5           30.0         14        Yes
#
#                                                  BlockchainIs BlockchainOrg  \
# Respondent
# 1                                                         NaN           NaN
# 2           Useful across many domains and could change ma...           NaN
# 3                                                         NaN           NaN
# 4           Useful for decentralized currency (i.e., Bitcoin)    Not at all
# 5                                                         NaN    Not at all
#
#                      CareerSat                                  CodeRev  \
# Respondent
# 1                          NaN                                      NaN
# 2                          NaN                                      NaN
# 3           Slightly satisfied                                       No
# 4               Very satisfied                                       No
# 5            Very dissatisfied  Yes, because I see value in code review
#
#             CodeRevHrs CompFreq  CompTotal  \
# Respondent
# 1                  NaN      NaN        NaN
# 2                  NaN      NaN        NaN
# 3                  NaN  Monthly    23000.0
# 4                  NaN   Yearly    61000.0
# 5                  NaN      NaN        NaN
#
#                                         Containers  ConvertedComp  \
# Respondent
# 1                          I do not use containers            NaN
# 2                          I do not use containers            NaN
# 3                          I do not use containers         8820.0
# 4                          I do not use containers        61000.0
# 5           Outside of work, for personal projects            NaN
#
#                            Country          CurrencyDesc CurrencySymbol  \
# Respondent
# 1                   United Kingdom                   NaN            NaN
# 2           Bosnia and Herzegovina                   NaN            NaN
# 3                         Thailand             Thai baht            THB
# 4                    United States  United States dollar            USD
# 5                          Ukraine     Ukrainian hryvnia            UAH
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                                           DatabaseWorkedWith Dependents  \
# Respondent
# 1                                                     SQLite         No
# 2                                                        NaN         No
# 3                                                 PostgreSQL        Yes
# 4                                               MySQL;SQLite         No
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite         No
#
#                                               DevEnviron  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm
# 2                                           Atom;PyCharm
# 3                                 Vim;Visual Studio Code
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code
# 5                                 IntelliJ;Notepad++;Vim
#
#                                                       DevType  \
# Respondent
# 1                                                         NaN
# 2           Developer, desktop or enterprise applications;...
# 3           Designer;Developer, back-end;Developer, front-...
# 4                                       Developer, full-stack
# 5           Academic researcher;Developer, desktop or ente...
#
#                                                       EdLevel  \
# Respondent
# 1                                   Primary/elementary school
# 2           Secondary school (e.g. American high school, G...
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                    Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                                         Employment  \
# Respondent
# 1           Not employed, and not looking for work
# 2               Not employed, but looking for work
# 3                               Employed full-time
# 4                               Employed full-time
# 5                               Employed full-time
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                                            Ethnicity  \
# Respondent
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                       White or of European descent
# 5           White or of European descent;Multiracial
#
#                         Extraversion FizzBuzz Gender Hobbyist  \
# Respondent
# 1                             Online      NaN    Man      Yes
# 2                             Online      NaN    Man       No
# 3           In real life (in person)       No    Man      Yes
# 4           In real life (in person)       No    Man       No
# 5           In real life (in person)       No    Man      Yes
#
#                                             ITperson                  ImpSyn  \
# Respondent
# 1           Fortunately, someone else has that title                     NaN
# 2                                                Yes                     NaN
# 3                                                Yes                 Average
# 4                                               SIGH  A little below average
# 5                                           Also Yes  A little above average
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                            JobSat  \
# Respondent
# 1                             NaN
# 2                             NaN
# 3              Slightly satisfied
# 4              Slightly satisfied
# 5           Slightly dissatisfied
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                      LanguageWorkedWith          LastHireDate  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python                   NaN
# 2                                   C++;HTML/CSS;Python  I've never had a job
# 3                                              HTML/CSS         1-2 years ago
# 4                                   C;C++;C#;Python;SQL  Less than a year ago
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA  Less than a year ago
#
#                                                       LastInt  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                         Interview with people in peer roles
# 4           Write code by hand (e.g., on a whiteboard);Int...
# 5           Write any code;Write code by hand (e.g., on a ...
#
#                                                    MainBranch  \
# Respondent
# 1                      I am a student who is learning to code
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                         MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                            NaN       NaN       NaN
# 2                            NaN       NaN       NaN
# 3           Not at all confident  Not sure  Not sure
# 4                 Very confident        No  Not sure
# 5             Somewhat confident       Yes        No
#
#                               MiscTechDesireNextYear MiscTechWorkedWith OffOn  \
# Respondent
# 1                                            Node.js            Node.js   Yes
# 2                                                NaN                NaN   Yes
# 3                                                NaN                NaN   Yes
# 4                                               .NET               .NET   Yes
# 5           Apache Spark;Hadoop;Node.js;React Native    Cordova;Node.js   Yes
#
#                   OpSys                                         OpenSource  \
# Respondent
# 1               Windows  The quality of OSS and closed source software ...
# 2               Windows  The quality of OSS and closed source software ...
# 3           Linux-based  The quality of OSS and closed source software ...
# 4               Windows  The quality of OSS and closed source software ...
# 5           Linux-based  OSS is, on average, of HIGHER quality than pro...
#
#                            OpenSourcer                   OrgSize  \
# Respondent
# 1                                Never                       NaN
# 2              Less than once per year                       NaN
# 3                                Never      100 to 499 employees
# 4                                Never      100 to 499 employees
# 5           Once a month or more often  10,000 or more employees
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                                  ResumeUpdate SOAccount  \
# Respondent
# 1                                                         NaN        No
# 2           Something else changed (education, award, medi...       Yes
# 3                            I was preparing for a job search       Yes
# 4                            I was preparing for a job search       Yes
# 5                            I was preparing for a job search       Yes
#
#                      SOComm                 SOFindAnswer  SOHowMuchTime  \
# Respondent
# 1                   Neutral           3-5 times per week  31-60 minutes
# 2             Yes, somewhat           3-5 times per week  11-30 minutes
# 3                   Neutral          6-10 times per week            NaN
# 4            No, not really           1-2 times per week  31-60 minutes
# 5           Yes, definitely  More than 10 times per week            NaN
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                  SONewContent  \
# Respondent
# 1           Tech articles written by other developers;Indu...
# 2           Tech articles written by other developers;Indu...
# 3           Tech meetups or events in your area;Courses on...
# 4           Tech articles written by other developers;Indu...
# 5           Tech meetups or events in your area;Courses on...
#
#                                      SOPartFreq  \
# Respondent
# 1                                           NaN
# 2               A few times per month or weekly
# 3           Less than once per month or monthly
# 4           Less than once per month or monthly
# 5               A few times per month or weekly
#
#                                SOTimeSaved        SOVisit1st  \
# Respondent
# 1           Stack Overflow was much faster              2017
# 2           Stack Overflow was much faster              2017
# 3                 They were about the same              2011
# 4           Stack Overflow was much faster              2014
# 5           Stack Overflow was much faster  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo ScreenName  \
# Respondent
# 1           Find answers to specific questions;Learn how t...   Username
# 2           Find answers to specific questions;Learn how t...   Username
# 3           Find answers to specific questions;Learn how t...   Username
# 4           Find answers to specific questions;Pass the ti...   Username
# 5                          Find answers to specific questions   Username
#
#                           Sexuality SocialMedia         Student  \
# Respondent
# 1           Straight / Heterosexual     Twitter              No
# 2           Straight / Heterosexual   Instagram  Yes, full-time
# 3           Straight / Heterosexual      Reddit              No
# 4           Straight / Heterosexual      Reddit              No
# 5           Straight / Heterosexual    Facebook              No
#
#                             SurveyEase           SurveyLength Trans  \
# Respondent
# 1           Neither easy nor difficult  Appropriate in length    No
# 2           Neither easy nor difficult  Appropriate in length    No
# 3           Neither easy nor difficult  Appropriate in length    No
# 4                                 Easy  Appropriate in length    No
# 5                                 Easy  Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                 UnitTests        WebFrameDesireNextYear  \
# Respondent
# 1                                     NaN                  Flask;jQuery
# 2                                     NaN                        Django
# 3               No, but I think we should                     Other(s):
# 4               No, but I think we should                           NaN
# 5           Yes, it's part of our process  Flask;jQuery;React.js;Spring
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                                       WelcomeChange  \
# Respondent
# 1           Just as welcome now as I felt last year
# 2           Just as welcome now as I felt last year
# 3           Just as welcome now as I felt last year
# 4           Just as welcome now as I felt last year
# 5           Just as welcome now as I felt last year
#
#                                                 WorkChallenge WorkLoc  \
# Respondent
# 1                                                         NaN     NaN
# 2                                                         NaN     NaN
# 3           Distracting work environment;Inadequate access...    Home
# 4                                                         NaN    Home
# 5           Being tasked with non-development work;Inadequ...  Office
#
#                                                      WorkPlan  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           There's no schedule or spec; I work on what se...
# 4           There's no schedule or spec; I work on what se...
# 5           There is a schedule and/or spec (made by me or...
#
#                                   WorkRemote  WorkWeekHrs YearsCode  \
# Respondent
# 1                                        NaN          NaN         4
# 2                                        NaN          NaN       NaN
# 3           Less than once per month / Never         40.0         3
# 4           Less than once per month / Never         80.0         3
# 5                      A few days each month         55.0        16
#
#                 YearsCodePro
# Respondent
# 1                        NaN
# 2                        NaN
# 3                          1
# 4           Less than 1 year
# 5                          9

# %%
df["YearsCode"].head(50)
# Out:
# Respondent
# 1                    4
# 2                  NaN
# 3                    3
# 4                    3
# 5                   16
# 6                   13
# 7                    6
# 8                    8
# 9                   12
# 10                  12
# 11                   2
# 12                   5
# 13                  17
# 14                  13
# 15                   3
# 16                  10
# 17                   5
# 18                  10
# 19                  14
# 20                   8
# 21                   5
# 22                  35
# 23                   3
# 24                   2
# 25                   2
# 26                  12
# 27                   7
# 28                  10
# 29                   4
# 30                   6
# 31    Less than 1 year
# 32                   3
# 33                   6
# 34    Less than 1 year
# 35                  14
# 36                  10
# 37                   7
# 38                  30
# 39                  30
# 40                   5
# 41                   4
# 42                   8
# 43                   9
# 44                  26
# 45                  40
# 46                  19
# 47                  35
# 48                   2
# 49                  15
# 50                   7
# Name: YearsCode, dtype: object

# %%
df["YearsCode"] = df["YearsCode"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-968a8c6d2a03> in <module>
# ----> 1 df["YearsCode"] = df["YearsCode"].astype(float)
#
# d:\programming\tutorials\corey-schafer\pandas\venv\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5535         else:
#    5536             # else, only a single dtype is given
# -> 5537             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5538             return self._constructor(new_data).__finalize__(self, method="astype")
#    5539
#
# d:\programming\tutorials\corey-schafer\pandas\venv\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# d:\programming\tutorials\corey-schafer\pandas\venv\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# d:\programming\tutorials\corey-schafer\pandas\venv\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     587             vals1d = values.ravel()
#     588             try:
# --> 589                 values = astype_nansafe(vals1d, dtype, copy=True)
#     590             except (ValueError, TypeError):
#     591                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# d:\programming\tutorials\corey-schafer\pandas\venv\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     987     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     988         # Explicit copy, or required since NumPy can't view from / to object.
# --> 989         return arr.astype(dtype, copy=True)
#     990
#     991     return arr.view(dtype)
#
# ValueError: could not convert string to float: 'Less than 1 year'

# %%
df["YearsCode"].value_counts()
# Out:
# 5                     7047
# 10                    6777
# 6                     6179
# 4                     5729
# 8                     5361
# 7                     5320
# 3                     5179
# 2                     3974
# 15                    3942
# 20                    3636
# 12                    3530
# 9                     3360
# 11                    2265
# 14                    2126
# 13                    2036
# 18                    1900
# 1                     1814
# 25                    1657
# 16                    1593
# 30                    1532
# Less than 1 year      1367
# 17                    1349
# 19                    1018
# 22                    1016
# 35                     873
# 23                     745
# 21                     715
# 24                     693
# 40                     497
# 28                     465
# 32                     420
# 26                     409
# 27                     408
# 33                     353
# 38                     340
# 34                     327
# 37                     321
# 36                     308
# 29                     234
# 31                     202
# 39                     170
# More than 50 years     126
# 42                     115
# 45                     113
# 41                      92
# 43                      83
# 44                      52
# 50                      51
# 47                      36
# 48                      31
# 46                      27
# 49                      25
# Name: YearsCode, dtype: int64

# %%
df["YearsCode"].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df["YearsCode"].replace("Less than 1 year", 0, inplace = True)
df["YearsCode"].replace("More than 50 years", 51, inplace = True)

# %%
df["YearsCode"] = df["YearsCode"].astype(float)

# %%
df["YearsCode"].mean()
# Out:
# 11.662114216834588

# %%
df["YearsCode"].median()
# Out:
# 9.0
