# %%
import pandas as pd

# %%
# Set DataFrame and DataFrameSchema
df = pd.read_csv("data/survey_results_public.csv", index_col = "Respondent")
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col = "Column")
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
# Sort by Country name ascending order and applies to DataFrame
df.sort_values(by = "Country", inplace = True)

# %%
# Show head = 50 of Column Country
df["Country"].head(50)
# Out:
# Respondent
# 1             United Kingdom
# 2     Bosnia and Herzegovina
# 3                   Thailand
# 4              United States
# 5                    Ukraine
# 6                     Canada
# 7                    Ukraine
# 8                      India
# 9                New Zealand
# 10                     India
# 11       Antigua and Barbuda
# 12                    Canada
# 13             United States
# 14                   Germany
# 15                     India
# 16            United Kingdom
# 17                 Australia
# 18        Russian Federation
# 19                    Brazil
# 20                 Lithuania
# 21                    Canada
# 22             United States
# 23             United States
# 24                    Israel
# 25              South Africa
# 26             United States
# 27                  Colombia
# 28                    Turkey
# 29             United States
# 30               Switzerland
# 31                    Canada
# ...

# %%
# Show the 50 rows of the top of DataFrame only the Columns: Country and Converted Comp
df[["Country", "ConvertedComp"]].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 39258       Afghanistan        19152.0
# 63129       Afghanistan      1000000.0
# 85715       Afghanistan            NaN
# 50767       Afghanistan            NaN
# 2782        Afghanistan            NaN
# 63019       Afghanistan            NaN
# 6417        Afghanistan            NaN
# 40000       Afghanistan            NaN
# 88731       Afghanistan            NaN
# 48436       Afghanistan         4464.0
# 10746       Afghanistan         3996.0
# 62525       Afghanistan            NaN
# 49702       Afghanistan            NaN
# 33178       Afghanistan            NaN
# 60946       Afghanistan            NaN
# 86362       Afghanistan            NaN
# 88582       Afghanistan            NaN
# 28638       Afghanistan            0.0
# 722         Afghanistan            0.0
# 26340       Afghanistan            NaN
# 86932       Afghanistan            NaN
# 85825       Afghanistan            NaN
# 7085        Afghanistan        14364.0
# ...

# %%
# Sort by ascending Country name and descending ConvertedComp
df[["Country", "ConvertedComp"]].sort_values(
    by = ["Country", "ConvertedComp"], ascending = [True, False])
# Out:
#                 Country  ConvertedComp
# Respondent
# 63129       Afghanistan      1000000.0
# 50499       Afghanistan       153216.0
# 39258       Afghanistan        19152.0
# 58450       Afghanistan        17556.0
# 7085        Afghanistan        14364.0
# ...                 ...            ...
# 88062               NaN            NaN
# 88076               NaN            NaN
# 88601               NaN            NaN
# 88802               NaN            NaN
# 88816               NaN            NaN
#
# [88883 rows x 2 columns]

# %%
df["ConvertedComp"].nlargest(10)
# Out:
# Respondent
# 58      2000000.0
# 102     2000000.0
# 166     2000000.0
# 436     2000000.0
# 452     2000000.0
# 491     2000000.0
# 539     2000000.0
# 770     2000000.0
# 789     2000000.0
# 1232    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, "ConvertedComp")
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 58          I am a developer by profession      Yes
# 102         I am a developer by profession       No
# 166         I am a developer by profession      Yes
# 436         I am a developer by profession      Yes
# 452         I am a developer by profession      Yes
# 491         I am a developer by profession      Yes
# 539         I am a developer by profession       No
# 770         I am a developer by profession      Yes
# 789         I am a developer by profession      Yes
# 1232        I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 58                                 Once a month or more often
# 102                                                     Never
# 166                                   Less than once per year
# 436                                   Less than once per year
# ...

# %%
df["ConvertedComp"].nsmallest(10)
# Out:
# Respondent
# 280     0.0
# 293     0.0
# 722     0.0
# 1105    0.0
# 1501    0.0
# 1685    0.0
# 1782    0.0
# 2019    0.0
# 2095    0.0
# 2665    0.0
# Name: ConvertedComp, dtype: float64

# %%
df.nsmallest(10, "ConvertedComp")
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 280         I am a developer by profession      Yes
# 293         I am a developer by profession      Yes
# 722         I am a developer by profession       No
# 1105        I am a developer by profession       No
# 1501        I am a developer by profession      Yes
# 1685        I am a developer by profession      Yes
# 1782        I am a developer by profession      Yes
# 2019        I am a developer by profession       No
# 2095        I am a developer by profession      Yes
# 2665        I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 280                                   Less than once per year
# 293                                   Less than once per year
# 722         Less than once a month but more than once per ...
# 1105                                                    Never
# ...
